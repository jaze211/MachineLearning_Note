# %%
import pandas as pd

data = {
    'STT': [1,2,3,4,5,6,7],
    'Màu da': ['Sẫm','Sẫm','Sáng','Ngăm','Ngăm','Sáng','Nâu'],
    'Tầm vóc': ['Trung bình','Cao','Thấp','Thấp','Trung bình','Trung bình','Trung bình'],
    'Thể trạng': ['Nhẹ','Trung bình','Trung bình','Trung bình','Nặng','Nặng','Nhẹ'],
    'Dùng kem': ['Không','Có','Có','Không','Không','Có','Có'],
    'Tình trạng da': ['Cháy nắng','Không','Không','Cháy nắng','Cháy nắng','Không','?']
}

df = pd.DataFrame(data)
df
# Out:
#    STT Màu da     Tầm vóc   Thể trạng Dùng kem Tình trạng da
# 0    1    Sẫm  Trung bình         Nhẹ    Không     Cháy nắng
# 1    2    Sẫm         Cao  Trung bình       Có         Không
# 2    3   Sáng        Thấp  Trung bình       Có         Không
# 3    4   Ngăm        Thấp  Trung bình    Không     Cháy nắng
# 4    5   Ngăm  Trung bình        Nặng    Không     Cháy nắng
# 5    6   Sáng  Trung bình        Nặng       Có         Không
# 6    7    Nâu  Trung bình         Nhẹ       Có             ?

# %%
prediction_tree1 = "Không"  # mẫu 7 dùng kem = Có
prediction_tree1
# Out:
# 'Không'

# %%
prediction_tree2 = "Cháy nắng"  # màu da = Nâu
prediction_tree2
# Out:
# 'Cháy nắng'

# %%
prediction_tree3 = "Cháy nắng"  # thể trạng = Nhẹ
prediction_tree3
# Out:
# 'Cháy nắng'

# %%
votes = [prediction_tree1, prediction_tree2, prediction_tree3]
votes
# Out:
# ['Không', 'Cháy nắng', 'Cháy nắng']

# %%
from collections import Counter
Counter(votes)
# Out:
# Counter({'Không': 1, 'Cháy nắng': 2})
